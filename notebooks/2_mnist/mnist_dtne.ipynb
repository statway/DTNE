# %%
import pickle
import time
with open('./mnist_X.dat', 'rb') as infile:
    X = pickle.load(infile)
with open('./mnist_color.dat', 'rb') as infile:
    color = pickle.load(infile)

# %%
import matplotlib.pyplot as plt

# %%
from dtne import *

# %%
start_time = time.time()
embedding = DTNE(k_neighbors =5)
Y = embedding.fit_transform(X)
end_time = time.time()
print('The code runs {:.0f}s.'.format(end_time - start_time))
plt.scatter(Y[:,0], Y[:,1], c=color,s=0.01,cmap='jet')
# Out:
# hello 9 10
# C:\Anaconda3\lib\site-packages\sklearn\manifold\_mds.py:319: UserWarning: Explicit initial positions passed: performing only one init of the MDS instead of 4
#   warnings.warn(
# The code runs 31s.

# %%
start_time = time.time()
embedding = DTNE(k_neighbors =10,l1=10)
Y = embedding.fit_transform(X)
end_time = time.time()
print('The code runs {:.0f}s.'.format(end_time - start_time))
plt.scatter(Y[:,0], Y[:,1], c=color,s=0.01,cmap='jet')
# Out:
# hello 10 11
# C:\Anaconda3\lib\site-packages\sklearn\manifold\_mds.py:319: UserWarning: Explicit initial positions passed: performing only one init of the MDS instead of 4
#   warnings.warn(
# The code runs 39s.

# %%
start_time = time.time()
embedding = DTNE(k_neighbors =8,kernel = 'umap')
Y = embedding.fit_transform(X)
end_time = time.time()
print('The code runs {:.0f}s.'.format(end_time - start_time))
plt.scatter(Y[:,0], Y[:,1], c=color,s=0.01,cmap='jet')
# Out:
# WARNING: You’re trying to run this on 100 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# hello 9 10
# C:\Anaconda3\lib\site-packages\sklearn\manifold\_mds.py:319: UserWarning: Explicit initial positions passed: performing only one init of the MDS instead of 4
#   warnings.warn(
# The code runs 29s.
